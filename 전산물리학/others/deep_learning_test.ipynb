# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0-rc0

# %%
from tensorflow.keras.datasets import mnist
(trimages,trlabels),(teimages,telabels) = mnist.load_data()
digit = trimages[6974]
digit_test = trlabels[6974]

import matplotlib.pyplot as plt
# print(digit_test)
# plt.imshow(digit, cmap=plt.cm.binary)

plt.figure(figsize=(100,100))
for i in range(10000):
    plt.subplot(100,100,i+1)
    plt.imshow(trimages[i], cmap=plt.cm.binary)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 13
#      11 for i in range(10000):
#      12     plt.subplot(100,100,i+1)
# ---> 13     plt.imshow(trimages[i], cmap=plt.cm.binary)
#
# File c:\Users\faran\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2668, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2662 @_copy_docstring_and_deprecators(Axes.imshow)
#    2663 def imshow(
#    2664         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2665         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2666         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2667         resample=None, url=None, data=None, **kwargs):
# -> 2668     __ret = gca().imshow(
# ...

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

fashion_mnist = keras.datasets.fashion_mnist

{training_images, training_labels}, {test_images, test_labels} == fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

training_images = training_images / 255.0
test_images = test_images / 255.0

# model = keras.Sequential([
#     keraas.layers.Flatten(input_shape=(28, 28)),
#     keraas.layers.Dense(128, activation=tf.nn.relu),
#     keraas.layers.Dense(10, activation=tf.nn.softmax)
# ])

# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# model.fit(training_images, training_labels, epochs=5)

# test_loss, test_acc = model.evaluate(test_images, test_labels)
# print('Test accuracy:', test_acc)

# predictions = model.predict(test_images)
# print(predictions[0])

plt.figure(figsize=(10,10))
plt.imshow(test_images[0])
plt.colorbar()
plt.grid(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5 import matplotlib.pyplot as plt
#       7 fashion_mnist = keras.datasets.fashion_mnist
# ----> 9 {training_images, training_labels}, {test_images, test_labels} == fashion_mnist.load_data()
#      11 class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#      12                'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
#      14 training_images = training_images / 255.0
#
# NameError: name 'training_images' is not defined
